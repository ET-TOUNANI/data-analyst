# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# %%
# you can either ignore the header row of the CSV file or specify the column names using the name parameter
data = pd.read_csv("input/wdbc.data",header=None)
pd.set_option("display.max_columns", 30)
data.head()
# Out:
#          0  1      2      3       4       5        6        7       8   \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#         9       10       11      12      13     14  ...       17       18  \
# 0  0.14710  0.2419  0.07871  1.0950  0.9053  8.589  ...  0.04904  0.05373
# 1  0.07017  0.1812  0.05667  0.5435  0.7339  3.398  ...  0.01308  0.01860
# 2  0.12790  0.2069  0.05999  0.7456  0.7869  4.585  ...  0.04006  0.03832
# 3  0.10520  0.2597  0.09744  0.4956  1.1560  3.445  ...  0.07458  0.05661
# 4  0.10430  0.1809  0.05883  0.7572  0.7813  5.438  ...  0.02461  0.05688
#
#         19       20        21     22     23      24      25      26      27  \
# ...

# %%
# how to transform the data of an column 
transform =lambda x:0 if x =="M"else 1
data[1]=data[1].apply(transform)
data.tail()

# we don't need the first and the seconf column so we wwil ignore it
X=data.iloc[:,2:]

# %%
def center_reduite(x):
    return (x-x.mean())/np.std(x)

# %%
X_cr = X.apply(center_reduite)
M_corr=X_cr.corr()
# Out:
#           2         3         4         5         6         7         8   \
# 2   1.000000  0.323782  0.997855  0.987357  0.170581  0.506124  0.676764
# 3   0.323782  1.000000  0.329533  0.321086 -0.023389  0.236702  0.302418
# 4   0.997855  0.329533  1.000000  0.986507  0.207278  0.556936  0.716136
# 5   0.987357  0.321086  0.986507  1.000000  0.177028  0.498502  0.685983
# 6   0.170581 -0.023389  0.207278  0.177028  1.000000  0.659123  0.521984
# 7   0.506124  0.236702  0.556936  0.498502  0.659123  1.000000  0.883121
# 8   0.676764  0.302418  0.716136  0.685983  0.521984  0.883121  1.000000
# 9   0.822529  0.293464  0.850977  0.823269  0.553695  0.831135  0.921391
# 10  0.147741  0.071401  0.183027  0.151293  0.557775  0.602641  0.500667
# 11 -0.311631 -0.076437 -0.261477 -0.283110  0.584792  0.565369  0.336783
# 12  0.679090  0.275869  0.691765  0.732562  0.301467  0.497473  0.631925
# 13 -0.097317  0.386358 -0.086761 -0.066280  0.068406  0.046205  0.076218
# ...

# %%
def my_pca(X):
    # compute the covariance matrix
    cov = np.cov(X.T)
    # compute the eigenvalues and eigenvectors of the covariance matrix
    eig_vals, eig_vecs = np.linalg.eig(cov)
    # sort the eigenvalues in descending order
    idx = eig_vals.argsort()[::-1]
    eig_vals = eig_vals[idx]
    eig_vecs = eig_vecs[:, idx]
    # return the eigenvalues and eigenvectors
    return eig_vals

my_pca(X_cr)
# Out:
# array([1.33049908e+01, 5.70137460e+00, 2.82291016e+00, 1.98412752e+00,
#        1.65163324e+00, 1.20948224e+00, 6.76408882e-01, 4.77456255e-01,
#        4.17628782e-01, 3.51310875e-01, 2.94433153e-01, 2.61621161e-01,
#        2.41782421e-01, 1.57286149e-01, 9.43006956e-02, 8.00034045e-02,
#        5.95036135e-02, 5.27114222e-02, 4.95647002e-02, 3.12142606e-02,
#        3.00256631e-02, 2.74877113e-02, 2.43836914e-02, 1.80867940e-02,
#        1.55085271e-02, 8.19203712e-03, 6.91261258e-03, 1.59213600e-03,
#        7.50121413e-04, 1.33279057e-04])

# %%
# Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_cr)

# Plot the transformed data
plt.scatter(X_pca[:, 0], X_pca[:, 1], c="r")
plt.xlabel('Col1')
plt.ylabel('Col2')
plt.show()
